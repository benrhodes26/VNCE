# %%
import numpy as np
import os
from matplotlib import pyplot as plt
from scipy.io import loadmat

# %matplotlib inline

# %%
data_dir = '/afs/inf.ed.ac.uk/user/s17/s1771906/masters-project/ben-rhodes-masters-project/proposal/data/usps'
loaded5by5 = np.load(os.path.join(data_dir, 'usps_5by5patches.npz'))
X_5by5 = loaded5by5['train']
X_test_5by5 = loaded5by5['test']

# %%
print('there are {} training examples in 5by5'.format(len(X_5by5)))
print('there are {} test examples in 5by5'.format(len(X_test_5by5)))
# Out:
# there are 64162 training examples in 5by5
# there are 16041 test examples in 5by5

# %%
fig, axs = plt.subplots(10, 5, figsize=(10, 10))
axs = axs.ravel()
ax_id = 0
for i in range(0, 500, 10):
    axs[ax_id].imshow(X_5by5[i].reshape(5, 5))#
    ax_id += 1
fig.tight_layout()

# %% [markdown]
# #  4x4 patches

# %%
data_dir = '/afs/inf.ed.ac.uk/user/s17/s1771906/masters-project/ben-rhodes-masters-project/proposal/data/usps'
loaded4by4 = np.load(os.path.join(data_dir, 'usps_4by4patches.npz'))
X_4by4 = loaded4by4['train']
X_test_4by4 = loaded4by4['test']

# %%
print('there are {} training examples in 4by4'.format(len(X_4by4)))
print('there are {} test examples in 4by4'.format(len(X_test_4by4)))
# Out:
# there are 97143 training examples in 4by4
# there are 24286 test examples in 4by4

# %%
fig, axs = plt.subplots(10, 5, figsize=(10, 10))
axs = axs.ravel()
ax_id = 0
for i in range(0, 500, 10):
    axs[ax_id].imshow(X_4by4[i].reshape(4, 4))
    ax_id += 1
fig.tight_layout()

# %% [markdown]
# #  3x3 patches

# %%
data_dir = '/afs/inf.ed.ac.uk/user/s17/s1771906/masters-project/ben-rhodes-masters-project/proposal/data/usps'
loaded3by3 = np.load(os.path.join(data_dir, 'usps_3by3patches.npz'))
X_3by3 = loaded3by3['train']
X_test_3by3 = loaded3by3['test']

# %%
print('there are {} training examples in 3by3'.format(len(X_3by3)))
print('there are {} training examples in 3by3'.format(len(X_test_3by3)))
# Out:
# there are 130096 training examples in 3by3
# there are 32525 training examples in 3by3

# %%
fig, axs = plt.subplots(10, 5, figsize=(10, 10))
axs = axs.ravel()
ax_id = 0
for i in range(0, 500, 10):
    axs[ax_id].imshow(X_3by3[i].reshape(3, 3))#
    ax_id += 1
